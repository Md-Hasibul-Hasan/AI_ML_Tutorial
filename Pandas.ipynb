# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Creating Series

# %%
labels = ['a', 'b', 'c']
li = [10,20,30]
arr = np.array([10,20,30])
dic = {"a":10,2:20,3:30}

# %%
pd.Series(li,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(dic)
# Out:
# a    10
# 2    20
# 3    30
# dtype: int64

# %% [markdown]
# # Data Frame

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
pd.DataFrame(data)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
pd.DataFrame(data_list)
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
col = ["Name", "age", "city", "salary"]
idx = [1,2,3,4]
pd.DataFrame(data_list,index=idx, columns=col)
# Out:
#     Name  age      city  salary
# 1   John   28  New York   65000
# 2   Anna   34     Paris   70000
# 3  Peter   29    Berlin   62000
# 4  Linda   42    London   85000

# %% [markdown]
# # Selection and Indexing of Columns

# %%
dt = pd.DataFrame(data_list,index=idx, columns=col)
dt
# Out:
#     Name  age      city  salary
# 1   John   28  New York   65000
# 2   Anna   34     Paris   70000
# 3  Peter   29    Berlin   62000
# 4  Linda   42    London   85000

# %%
dt['Name']
# Out:
# 1     John
# 2     Anna
# 3    Peter
# 4    Linda
# Name: Name, dtype: str

# %%
dt[['Name','city']]
# Out:
#     Name      city
# 1   John  New York
# 2   Anna     Paris
# 3  Peter    Berlin
# 4  Linda    London

# %%
dt['id'] = [101,102,103,104] # add column
dt
# Out:
#     Name  age      city  salary   id
# 1   John   28  New York   65000  101
# 2   Anna   34     Paris   70000  102
# 3  Peter   29    Berlin   62000  103
# 4  Linda   42    London   85000  104

# %%
dt.drop('id',axis=1) # axis=0 row , axis=1 column
# Out:
#     Name  age      city  salary
# 1   John   28  New York   65000
# 2   Anna   34     Paris   70000
# 3  Peter   29    Berlin   62000
# 4  Linda   42    London   85000

# %%
dt.drop(3,axis=0)
# Out:
#     Name  age      city  salary   id
# 1   John   28  New York   65000  101
# 2   Anna   34     Paris   70000  102
# 4  Linda   42    London   85000  104

# %%
dt.drop('id',axis=1, inplace=True) # delete from memory
dt
# Out:
#     Name  age      city  salary
# 1   John   28  New York   65000
# 2   Anna   34     Paris   70000
# 3  Peter   29    Berlin   62000
# 4  Linda   42    London   85000

# %%
dt.drop(['Name','city'],axis=1, inplace=True)
dt
# Out:
#    age  salary
# 1   28   65000
# 2   34   70000
# 3   29   62000
# 4   42   85000

# %% [markdown]
# # Selection and Indexing of Rows

# %%
dt = pd.DataFrame(data_list,index=idx, columns=col)
dt
# Out:
#     Name  age      city  salary
# 1   John   28  New York   65000
# 2   Anna   34     Paris   70000
# 3  Peter   29    Berlin   62000
# 4  Linda   42    London   85000

# %%
dt.loc[1]
# Out:
# Name          John
# age             28
# city      New York
# salary       65000
# Name: 1, dtype: object

# %%
dt.loc[[1,2]]
# Out:
#    Name  age      city  salary
# 1  John   28  New York   65000
# 2  Anna   34     Paris   70000

# %%
dt.iloc[1]
# Out:
# Name       Anna
# age          34
# city      Paris
# salary    70000
# Name: 2, dtype: object

# %% [markdown]
# # Selecting Subsets of Rows and Columns

# %%
dt
# Out:
#     Name  age      city  salary
# 1   John   28  New York   65000
# 2   Anna   34     Paris   70000
# 3  Peter   29    Berlin   62000
# 4  Linda   42    London   85000

# %%
dt.loc[1]["Name"]
# Out:
# 'John'

# %%
dt.loc[[1,2]]   [["Name",'city']]
# Out:
#    Name      city
# 1  John  New York
# 2  Anna     Paris

# %% [markdown]
# # Conditional Selection

# %%
dt
# Out:
#     Name  age      city  salary
# 1   John   28  New York   65000
# 2   Anna   34     Paris   70000
# 3  Peter   29    Berlin   62000
# 4  Linda   42    London   85000

# %%
# age above 30
dt['age']>30
# Out:
# 1    False
# 2     True
# 3    False
# 4     True
# Name: age, dtype: bool

# %%
dt[dt["age"]>30]
# Out:
#     Name  age    city  salary
# 2   Anna   34   Paris   70000
# 4  Linda   42  London   85000

# %%
# age > 30 and city Paris
x = (dt['city'] == "Paris") | (dt['city'] == "London") & (dt['age'] > 30)
x
# Out:
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
dt[x]
# Out:
#     Name  age    city  salary
# 2   Anna   34   Paris   70000
# 4  Linda   42  London   85000

# %% [markdown]
# # Missing Data

# %%
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [1, 2, 3, 4, 5],
    'C': [1, 2, 3, np.nan, np.nan],
    'D': [1, np.nan, np.nan, np.nan, 5]
}
df = pd.DataFrame(data)
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.isna() #checks null value
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False   True
# 2   True  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
df.isna().sum()
# Out:
# A    1
# B    0
# C    2
# D    3
# dtype: int64

# %%
df.isna().any()
# Out:
# A     True
# B    False
# C     True
# D     True
# dtype: bool

# %% [markdown]
# # Removing Missing Data

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.dropna()  # remove all rows which includes Null values
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
df.dropna(thresh=3) # 3 non-null values thakbe
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 4  5.0  5  NaN  5.0

# %% [markdown]
# # Filling null/missing data

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.fillna(0)  # replace null with 0
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  0.0
# 2  0.0  3  3.0  0.0
# 3  4.0  4  0.0  0.0
# 4  5.0  5  0.0  5.0

# %%
val = {'A':'xxx','B':1000,'C':2000, 'D':'xyz'}
df.fillna(val)
# Out:
#      A  B       C    D
# 0  1.0  1     1.0  1.0
# 1  2.0  2     2.0  xyz
# 2  xxx  3     3.0  xyz
# 3  4.0  4  2000.0  xyz
# 4  5.0  5  2000.0  5.0

# %% [markdown]
# # Merging Joining Concatination

# %%
em = pd.DataFrame({
    'employee_id': [1, 2, 3, 4, 5],
    'name': ['John', 'Anna', 'Peter', 'Linda', 'Bob'],
    'department': ['HR', 'IT', 'Finance', 'IT', 'HR']
})


sal = pd.DataFrame({
    'employee_id': [1, 2, 3, 6, 7],
    'salary': [60000, 80000, 65000, 70000, 90000],
    'bonus': [5000, 10000, 7000, 8000, 12000]
})

# %%
em
# Out:
#    employee_id   name department
# 0            1   John         HR
# 1            2   Anna         IT
# 2            3  Peter    Finance
# 3            4  Linda         IT
# 4            5    Bob         HR

# %%
sal
# Out:
#    employee_id  salary  bonus
# 0            1   60000   5000
# 1            2   80000  10000
# 2            3   65000   7000
# 3            6   70000   8000
# 4            7   90000  12000

# %%
pd.merge(em,sal,on='employee_id',how='inner')
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000

# %%
pd.merge(em,sal,on='employee_id',how='outer')
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN
# 5            6    NaN        NaN  70000.0   8000.0
# 6            7    NaN        NaN  90000.0  12000.0

# %%
pd.merge(em,sal,on='employee_id',how='left')
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN

# %%
pd.merge(em,sal,on='employee_id',how='right')
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000
# 3            6    NaN        NaN   70000   8000
# 4            7    NaN        NaN   90000  12000

# %% [markdown]
# # Concatination

# %%
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2'],
    'B': ['B0', 'B1', 'B2'],
    'C': ['C0', 'C1', 'C2']
})

df2 = pd.DataFrame({
    'A': ['A3', 'A4', 'A5'],
    'B': ['B3', 'B4', 'B5'],
    'C': ['C3', 'C4', 'C5']
})

# %%
df1
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2

# %%
df2
# Out:
#     A   B   C
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
pd.concat([df1,df2],axis=0)
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     A   B   C   A   B   C
# 0  A0  B0  C0  A3  B3  C3
# 1  A1  B1  C1  A4  B4  C4
# 2  A2  B2  C2  A5  B5  C5

# %% [markdown]
# # Joining

# %%
df1 = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie']
}, index=[1, 2, 3])


df2 = pd.DataFrame({
    'score': [85, 90, 75]
}, index=[2, 3, 4])

# %%
df1
# Out:
#       name
# 1    Alice
# 2      Bob
# 3  Charlie

# %%
df2
# Out:
#    score
# 2     85
# 3     90
# 4     75

# %%
df1.join(df2)
# Out:
#       name  score
# 1    Alice    NaN
# 2      Bob   85.0
# 3  Charlie   90.0

# %%
df1.join(df2,how='inner')
# Out:
#       name  score
# 2      Bob     85
# 3  Charlie     90

# %%
df1.join(df2,how='outer')
# Out:
#       name  score
# 1    Alice    NaN
# 2      Bob   85.0
# 3  Charlie   90.0
# 4      NaN   75.0

# %% [markdown]
# # Group By Aggregation

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}
df = pd.DataFrame(data)
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
#Grp by category and calculate sum of sales
cat = df.groupby('Category')
for i,j in cat:
  print(f"{i}  {j}")
# Out:
# A    Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 2        A    S2    150        12 2023-01-03
# 4        A    S1    120         8 2023-01-05
# 6        A    S2    200        15 2023-01-07
# B    Category Store  Sales  Quantity       Date
# 1        B    S1    200        15 2023-01-02
# 3        B    S2    250        18 2023-01-04
# 5        B    S2    180        20 2023-01-06
# 7        B    S1    300        25 2023-01-08

# %%
sum = df.groupby('Category')['Sales'].sum()
sum
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
sum = df.groupby('Store')['Sales'].sum()
sum
# Out:
# Store
# S1    720
# S2    780
# Name: Sales, dtype: int64

# %%
sum = df.groupby(['Category','Store'])['Sales'].sum()
sum
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %%
# Aggregation: mean median mode std max min count
df['Sales'].mode()
# Out:
# 0    200
# Name: Sales, dtype: int64

# %%
df['Sales'].agg(['mean','median','max','min','count','sum'])
# Out:
# mean       187.5
# median     190.0
# max        300.0
# min        100.0
# count        8.0
# sum       1500.0
# Name: Sales, dtype: float64

# %% [markdown]
# # Pivot Table

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    954     16   John  January      Q1
# 1  2023-01-02       B   West    465     31   Mary  January      Q1
# 2  2023-01-03       C  North    912     39    Bob  January      Q1
# 3  2023-01-04       D  South    171     75  Alice  January      Q1
# 4  2023-01-05       A   East    913     63   John  January      Q1
# 5  2023-01-06       B   West    837     35   Mary  January      Q1
# 6  2023-01-07       C  North    579     70    Bob  January      Q1
# 7  2023-01-08       D  South    410     30  Alice  January      Q1
# 8  2023-01-09       A   East    782     61   John  January      Q1
# 9  2023-01-10       B   West    773     47   Mary  January      Q1
# 10 2023-01-11       C  North    164     58    Bob  January      Q1
# 11 2023-01-12       D  South    855     13  Alice  January      Q1
# 12 2023-01-13       A   East    723     86   John  January      Q1
# ...

# %%
pd.pivot_table(df, values='Sales', index='Region', columns='Product', aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     782.0    NaN    NaN    NaN
# North      NaN    NaN  579.0    NaN
# South      NaN    NaN    NaN  410.0
# West       NaN  773.0    NaN    NaN

# %%
pd.pivot_table(df, values=['Sales','Units'], index='Region', columns='Product', aggfunc='median')
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     782.0    NaN    NaN    NaN  63.0   NaN   NaN   NaN
# North      NaN    NaN  579.0    NaN   NaN   NaN  63.0   NaN
# South      NaN    NaN    NaN  410.0   NaN   NaN   NaN  34.0
# West       NaN  773.0    NaN    NaN   NaN  35.0   NaN   NaN

# %% [markdown]
# # Cross Tabs

# %%
# gives counts
pd.crosstab(index=df['Region'], columns=df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %% [markdown]
# # Operations

# %%
df1 = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})

df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
df1.shape
# Out:
# (5, 3)

# %%
df1.columns
# Out:
# Index(['A', 'B', 'C'], dtype='str')

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      int64
#  1   B       5 non-null      int64
#  2   C       5 non-null      int64
# dtypes: int64(3)
# memory usage: 252.0 bytes

# %%
df1.describe()
# Out:
#               A          B           C
# count  5.000000   5.000000    5.000000
# mean   3.000000  30.000000  300.000000
# std    1.581139  15.811388  158.113883
# min    1.000000  10.000000  100.000000
# 25%    2.000000  20.000000  200.000000
# 50%    3.000000  30.000000  300.000000
# 75%    4.000000  40.000000  400.000000
# max    5.000000  50.000000  500.000000

# %%
df1['A']+10
# Out:
# 0    11
# 1    12
# 2    13
# 3    14
# 4    15
# Name: A, dtype: int64

# %%
def sq(x):
  return x**2

# %%
df1['B^2'] = df1['B'].apply(sq)
df1
# Out:
#    A   B    C   B^2
# 0  1  10  100   100
# 1  2  20  200   400
# 2  3  30  300   900
# 3  4  40  400  1600
# 4  5  50  500  2500
